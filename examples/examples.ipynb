# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.insert(0, '..')

from calculate import compute_freqs
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
#Normally you would feed in a big list of electric fields computed from MD simulation
# Here we just use a small range, showing its affect on the symmetric stretch

field_strengths = np.linspace(0, -2, 11)
example_fields = np.array([np.zeros(11), field_strengths]).T

# %%
frame = 0

compute_freqs(example_fields, "../amoeba_params.json")
# Out:
# Computing Frequencies
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/open/lib/python3.14/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.1.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Parallel(n_jobs=8)]: Done   2 out of  11 | elapsed:    3.2s remaining:   14.6s
# [Parallel(n_jobs=8)]: Done   4 out of  11 | elapsed:    3.3s remaining:    5.8s
# [Parallel(n_jobs=8)]: Done   6 out of  11 | elapsed:    3.4s remaining:    2.9s
# [Parallel(n_jobs=8)]: Done   8 out of  11 | elapsed:    3.6s remaining:    1.3s
# [Parallel(n_jobs=8)]: Done  11 out of  11 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of  11 | elapsed:    1.2s remaining:    5.3s
# [Parallel(n_jobs=8)]: Done   4 out of  11 | elapsed:    1.2s remaining:    2.1s
# [Parallel(n_jobs=8)]: Done   6 out of  11 | elapsed:    1.2s remaining:    1.0s
# [Parallel(n_jobs=8)]: Done   8 out of  11 | elapsed:    1.2s remaining:    0.5s
# [Parallel(n_jobs=8)]: Done  11 out of  11 | elapsed:    2.2s finished

# %%
results = np.load("results.npz")

# %%
freqs = results['freqs']


plt.scatter(field_strengths, freqs[:,2])

plt.xlabel("Electric fields, (V/A)", fontsize=15)
plt.ylabel("Frequencies (cm $^{-1}$)", fontsize=15)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
